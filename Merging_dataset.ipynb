# %%
import pandas as pd
import numpy as np

# %%
i=pd.read_csv('E:\\python\\unix001\\imdb-top-1000.csv')
i
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating
# 0    The Shawshank Redemption          1994      142   Drama          9.3  \
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross
# ...

# %%
ipl=pd.read_csv('E:\\python\\unix001\\ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber
# 0    1312200   Ahmedabad  2022-05-29     2022        Final  \
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2
# 0               Rajasthan Royals               Gujarat Titans  \
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
c=pd.read_csv('E:\\python\\unix001\\courses.csv')
c
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
st=pd.read_csv('E:\\python\\unix001\\students.csv')
st
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
dec=pd.read_csv('E:\\python\\unix001\\reg-month2.csv')
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
nov=pd.read_csv('E:\\python\\unix001\\reg-month1.csv')
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
mt=pd.read_csv('E:\\python\\unix001\\matches.csv')
mt
# Out:
#       id  season       city        date                        team1
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision
# ...

# %%
dv=pd.read_csv('E:\\python\\unix001\\deliveries.csv')
dv
# Out:
#         match_id  inning                 batting_team
# 0              1       1          Sunrisers Hyderabad  \
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan  \
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
nd=pd.concat([nov,dec],keys=(['nov','dec']))
nd
# Out:
#         student_id  course_id
# nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
# ...

# %%
g=pd.concat([nov,dec])
g
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# ...

# %%
c
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
k=g.merge(c,how='inner',on='course_id').sort_values(by='student_id')
k
# Out:
#     student_id  course_id       course_name  price
# 2            1          1            python   2499
# 17           1          6          power bi   1899
# 44           1         10           pyspark   2499
# 28           1          9            plotly    699
# 13           2          5           tableau   2499
# 38           3          3     data analysis   4999
# 11           3          5           tableau   2499
# 31           7          8            pandas   1099
# 20           7          6          power bi   1899
# 40           7         10           pyspark   2499
# 52           7          2               sql   3499
# 49           7          7          ms sxcel   1599
# 46          11          7          ms sxcel   1599
# 32          11          8            pandas   1099
# 45          11         10           pyspark   2499
# 12          12          5           tableau   2499
# 42          12         10           pyspark   2499
# ...

# %%
k['price'].sum()
# Out:
# 154247

# %%
nov.merge(c,how='inner',on='course_id')['price'].sum()
# Out:
# 89175

# %%
dec.merge(c,how='inner',on='course_id')['price'].sum()
# Out:
# 65072

# %%
89175 +65072
# Out:
# 154247

# %%
j=pd.concat([nov,dec],keys=['nov','dec']).reset_index()

# %%
j.merge(c,how='inner',on='course_id').groupby('level_0')['price'].sum()
# Out:
# level_0
# dec    65072
# nov    89175
# Name: price, dtype: int64

# %%
st.head(2)
# Out:
#    student_id           name  partner
# 0           1  Kailash Harjo       23
# 1           2    Esha Butala        1

# %%
c.head(2)
# Out:
#    course_id course_name  price
# 0          1      python   2499
# 1          2         sql   3499

# %%
dec.head(2)
# Out:
#    student_id  course_id
# 0           3          5
# 1          16          7

# %%
nov.head(2)
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5

# %%
bm=pd.concat([nov,dec],keys=(['nov','dec'])).reset_index()

# %%
bmc=bm.merge(st,how='inner',on='student_id')
bmc
# Out:
#    level_0  level_1  student_id  course_id                name  partner
# 0      nov        0          23          1      Chhavi Lachman       18
# 1      nov        3          23          4      Chhavi Lachman       18
# 2      nov       18          23          3      Chhavi Lachman       18
# 3      nov       20          23          6      Chhavi Lachman       18
# 4      dec       20          23          9      Chhavi Lachman       18
# 5      dec       21          23          5      Chhavi Lachman       18
# 6      nov        1          15          5           Preet Sha       16
# 7      nov        9          15          1           Preet Sha       16
# 8      nov        2          18          6     Fardeen Mahabir       13
# 9      nov        5          18          1     Fardeen Mahabir       13
# 10     dec       13          18          8     Fardeen Mahabir       13
# 11     nov        4          16          9        Elias Dodiya       25
# ...

# %%
bmcd
# Out:
#    level_0  level_1  student_id  course_id                name  partner
# 3      nov        6           1          1       Kailash Harjo       23  \
# 19     nov       11           1          6       Kailash Harjo       23
# 42     dec       14           1         10       Kailash Harjo       23
# 25     dec       15           1          9       Kailash Harjo       23
# 33     dec       16           2          5         Esha Butala        1
# 31     dec        0           3          5      Parveen Bhalla        3
# 16     nov       24           3          3      Parveen Bhalla        3
# 35     nov        7           7          8        Tarun Thaker        9
# 48     dec        6           7          2        Tarun Thaker        9
# 38     dec        5           7          7        Tarun Thaker        9
# 20     dec       17           7          6        Tarun Thaker        9
# 43     nov       12           7         10        Tarun Thaker        9
# ...

# %%
f=bmcd.iloc[:,[4,6,7]].reset_index()

# %%
final=f.drop(columns='index')

# %%
final.sort_values('name').sum()
# Out:
# name           Chhavi LachmanChhavi LachmanChhavi LachmanChha...
# course_name    tableaupythonmachine learningdata analysispowe...
# price                                                     149950
# dtype: object

# %%
j.merge(c,how='inner',on='course_id').groupby('course_name')['price'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
nov.head(2)
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5

# %%
dec.head(2)
# Out:
#    student_id  course_id
# 0           3          5
# 1          16          7

# %%
un=nov.merge(dec,how='inner',on='student_id').sort_values('student_id')
un
# Out:
#     student_id  course_id_x  course_id_y
# 14           1            1           10
# 17           1            6            9
# 16           1            6           10
# 15           1            1            9
# 29           3            3            5
# 22           7           10            2
# 20           7            8            6
# 19           7            8            2
# 18           7            8            7
# 23           7           10            6
# 21           7           10            7
# 27          11            7           10
# 26          11            7            8
# 13          16            5            3
# 11          16            9            3
# 10          16            9            7
# 12          16            5            7
# 28          17            7           10
# 9           18            1            8
# 8           18            6            8
# 25          22            3            6
# 24          22            3            5
# ...

# %%
kj=np.intersect1d(nov['student_id'],dec['student_id'])
kj
# Out:
# array([ 1,  3,  7, 11, 16, 17, 18, 22, 23], dtype=int64)

# %%
st[st['student_id'].isin(kj)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
bmc
# Out:
#    level_0  level_1  student_id  course_id                name  partner
# 0      nov        0          23          1      Chhavi Lachman       18
# 1      nov        3          23          4      Chhavi Lachman       18
# 2      nov       18          23          3      Chhavi Lachman       18
# 3      nov       20          23          6      Chhavi Lachman       18
# 4      dec       20          23          9      Chhavi Lachman       18
# 5      dec       21          23          5      Chhavi Lachman       18
# 6      nov        1          15          5           Preet Sha       16
# 7      nov        9          15          1           Preet Sha       16
# 8      nov        2          18          6     Fardeen Mahabir       13
# 9      nov        5          18          1     Fardeen Mahabir       13
# 10     dec       13          18          8     Fardeen Mahabir       13
# 11     nov        4          16          9        Elias Dodiya       25
# ...

# %%
st.head(2)
# Out:
#    student_id           name  partner
# 0           1  Kailash Harjo       23
# 1           2    Esha Butala        1

# %%
st.merge(st,how='inner',left_on='partner',right_on='student_id')[['name_x','name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13    Pranab Natarajan          Yash Sethi
# 14           Preet Sha        Elias Dodiya
# 15        Elias Dodiya     Shashank D’Alia
# 16        Yasmin Palan        Tarun Thaker
# 17     Fardeen Mahabir      Munni Varghese
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota           Preet Sha
# ...

# %%
bmc['name'].value_counts().sort_values(ascending=False).head(3)
# Out:
# name
# Chhavi Lachman    6
# Tarun Thaker      5
# Elias Dodiya      4
# Name: count, dtype: int64

# %%
bmc.groupby(['student_id','name'])['name'].value_counts().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman    6
# 7           Tarun Thaker      5
# 1           Kailash Harjo     4
# Name: count, dtype: int64

# %%
mt
# Out:
#       id  season       city        date                        team1
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision
# ...

# %%
dv
# Out:
#         match_id  inning                 batting_team
# 0              1       1          Sunrisers Hyderabad  \
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan  \
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
only_six=dv[dv['batsman_runs']==6]
only_six.head(2)
# Out:
#     match_id  inning         batting_team                 bowling_team  over
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2  \
# 47         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     8
#
#     ball       batsman non_striker       bowler  is_super_over  ...  bye_runs
# 10     4     DA Warner    S Dhawan  A Choudhary              0  ...         0  \
# 47     4  MC Henriques    S Dhawan      TM Head              0  ...         0
#
#     legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs
# 10            0            0             0             6           0  \
# 47            0            0             0             6           0
#
#     total_runs  player_dismissed dismissal_kind fielder
# 10           6               NaN            NaN     NaN
# 47           6               NaN            NaN     NaN
#
# [2 rows x 21 columns]

# %%
six=only_six.merge(mt,how='inner',left_on='match_id',right_on='id').groupby('venue')['batsman_runs'].value_counts().sort_values(ascending=False)
six
# Out:
# venue                                                 batsman_runs
# M Chinnaswamy Stadium                                 6               873
# Wankhede Stadium                                      6               657
# Feroz Shah Kotla                                      6               636
# Eden Gardens                                          6               594
# MA Chidambaram Stadium, Chepauk                       6               507
# Rajiv Gandhi International Stadium, Uppal             6               492
# Punjab Cricket Association Stadium, Mohali            6               307
# Sawai Mansingh Stadium                                6               243
# Dr DY Patil Sports Academy                            6               173
# Maharashtra Cricket Association Stadium               6               169
# Subrata Roy Sahara Stadium                            6               141
# Sardar Patel Stadium, Motera                          6               130
# ...

# %%
match=mt['venue'].value_counts()
match
# Out:
# venue
# M Chinnaswamy Stadium                                   66
# Eden Gardens                                            61
# Feroz Shah Kotla                                        60
# Wankhede Stadium                                        57
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Maharashtra Cricket Association Stadium                 15
# Kingsmead                                               15
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
(six/match).sort_values(ascending=False).head(5)
# Out:
# venue                                                batsman_runs
# Holkar Cricket Stadium                               6               17.600000
# M Chinnaswamy Stadium                                6               13.227273
# Sharjah Cricket Stadium                              6               12.666667
# Himachal Pradesh Cricket Association Stadium         6               12.000000
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  6               11.727273
# Name: count, dtype: float64

# %%
dv.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
dv.head(60)
# Out:
#     match_id  inning         batting_team                 bowling_team  over
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1  \
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# ...

# %%
dv[dv['player_dismissed']!='NaN']
# Out:
#         match_id  inning                 batting_team
# 0              1       1          Sunrisers Hyderabad  \
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan  \
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
dv
# Out:
#         match_id  inning                 batting_team
# 0              1       1          Sunrisers Hyderabad  \
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan  \
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
dv.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(10)
# Out:
# bowler
# SL Malinga         170
# A Mishra           142
# DJ Bravo           137
# Harbhajan Singh    136
# PP Chawla          133
# R Vinay Kumar      125
# A Nehra            121
# Z Khan             119
# B Kumar            117
# R Ashwin           110
# Name: player_dismissed, dtype: int64

# %%
mt
# Out:
#       id  season       city        date                        team1
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision
# ...

# %%
total=mt.merge(dv,how='inner',left_on='id',right_on='match_id')
total
# Out:
#          id  season       city        date                team1
# 0         1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad  \
# 1         1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 2         1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 3         1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 4         1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# ...     ...     ...        ...         ...                  ...
# 150455  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
# 150456  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
# 150457  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
# 150458  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
# 150459  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                               team2                  toss_winner
# 0       Royal Challengers Bangalore  Royal Challengers Bangalore  \
# ...

# %%
total.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'match_id', 'inning', 'batting_team', 'bowling_team', 'over',
#        'ball', 'batsman', 'non_striker', 'bowler', 'is_super_over',
#        'wide_runs', 'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
total.groupby(['season','batsman'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs',ascending=False).drop_duplicates(subset='season',keep='first').sort_values('season')
# Out:
#       season       batsman  batsman_runs
# 115     2008      SE Marsh           616
# 229     2009     ML Hayden           572
# 446     2010  SR Tendulkar           618
# 502     2011      CH Gayle           608
# 684     2012      CH Gayle           733
# 910     2013    MEK Hussey           733
# 1088    2014    RV Uthappa           660
# 1148    2015     DA Warner           562
# 1383    2016       V Kohli           973
# 1422    2017     DA Warner           641
