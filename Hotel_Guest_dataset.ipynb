# %%
import pandas as pd
import numpy as np
import math

# %%
g=pd.read_csv('F:\\d_data\\New folder\\hotel_guests_dataset.csv')
g
# Out:
#                        guest_email  has_rewards room_type  amenities_fee
# 0            dsullivan@example.net        False     BASIC       8.324971  \
# 1             steven59@example.org        False     BASIC            NaN
# 2            brandon15@example.net        False     BASIC      22.269158
# 3     humphreyjennifer@example.net        False     BASIC      25.468647
# 4          joshuabrown@example.net        False     BASIC      19.778311
# ...                            ...          ...       ...            ...
# 1995         valerie83@example.org        False     BASIC       9.377198
# 1996        hartdaniel@example.org        False     BASIC      18.580052
# 1997            fbaker@example.org        False     BASIC      20.228473
# 1998   jenniferbradley@example.org        False     BASIC       8.730536
# 1999          travis58@example.net        False     BASIC      19.454490
#
#      checkin_date checkout_date   room_rate
# 0       04-Apr-20     23-Apr-20  146.834507  \
# ...

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   guest_email         2000 non-null   object
#  1   has_rewards         2000 non-null   bool
#  2   room_type           2000 non-null   object
#  3   amenities_fee       1816 non-null   float64
#  4   checkin_date        2000 non-null   object
#  5   checkout_date       1931 non-null   object
#  6   room_rate           2000 non-null   float64
#  7   billing_address     2000 non-null   object
#  8   credit_card_number  2000 non-null   int64
# dtypes: bool(1), float64(2), int64(1), object(5)
# memory usage: 127.1+ KB

# %%
g['amenities_fee'].fillna(value=17,inplace=True)

# %%
g
# Out:
#                        guest_email  has_rewards room_type  amenities_fee
# 0            dsullivan@example.net        False     BASIC       8.324971  \
# 1             steven59@example.org        False     BASIC      17.000000
# 2            brandon15@example.net        False     BASIC      22.269158
# 3     humphreyjennifer@example.net        False     BASIC      25.468647
# 4          joshuabrown@example.net        False     BASIC      19.778311
# ...                            ...          ...       ...            ...
# 1995         valerie83@example.org        False     BASIC       9.377198
# 1996        hartdaniel@example.org        False     BASIC      18.580052
# 1997            fbaker@example.org        False     BASIC      20.228473
# 1998   jenniferbradley@example.org        False     BASIC       8.730536
# 1999          travis58@example.net        False     BASIC      19.454490
#
#      checkin_date checkout_date   room_rate
# 0       04-Apr-20     23-Apr-20  146.834507  \
# ...

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   guest_email         2000 non-null   object
#  1   has_rewards         2000 non-null   bool
#  2   room_type           2000 non-null   object
#  3   amenities_fee       2000 non-null   float64
#  4   checkin_date        2000 non-null   object
#  5   checkout_date       1931 non-null   object
#  6   room_rate           2000 non-null   float64
#  7   billing_address     2000 non-null   object
#  8   credit_card_number  2000 non-null   int64
# dtypes: bool(1), float64(2), int64(1), object(5)
# memory usage: 127.1+ KB

# %%
g['checkin_date']=pd.to_datetime(g['checkin_date'])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8496\418448044.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   g['checkin_date']=pd.to_datetime(g['checkin_date'])

# %%
g
# Out:
#                        guest_email  has_rewards room_type  amenities_fee
# 0            dsullivan@example.net        False     BASIC       8.324971  \
# 1             steven59@example.org        False     BASIC      17.000000
# 2            brandon15@example.net        False     BASIC      22.269158
# 3     humphreyjennifer@example.net        False     BASIC      25.468647
# 4          joshuabrown@example.net        False     BASIC      19.778311
# ...                            ...          ...       ...            ...
# 1995         valerie83@example.org        False     BASIC       9.377198
# 1996        hartdaniel@example.org        False     BASIC      18.580052
# 1997            fbaker@example.org        False     BASIC      20.228473
# 1998   jenniferbradley@example.org        False     BASIC       8.730536
# 1999          travis58@example.net        False     BASIC      19.454490
#
#      checkin_date checkout_date   room_rate
# 0      2020-04-04     23-Apr-20  146.834507  \
# ...

# %%
g['checkout_date']=pd.to_datetime(g['checkout_date'])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8496\1037402952.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   g['checkout_date']=pd.to_datetime(g['checkout_date'])

# %%
g
# Out:
#                        guest_email  has_rewards room_type  amenities_fee
# 0            dsullivan@example.net        False     BASIC       8.324971  \
# 1             steven59@example.org        False     BASIC      17.000000
# 2            brandon15@example.net        False     BASIC      22.269158
# 3     humphreyjennifer@example.net        False     BASIC      25.468647
# 4          joshuabrown@example.net        False     BASIC      19.778311
# ...                            ...          ...       ...            ...
# 1995         valerie83@example.org        False     BASIC       9.377198
# 1996        hartdaniel@example.org        False     BASIC      18.580052
# 1997            fbaker@example.org        False     BASIC      20.228473
# 1998   jenniferbradley@example.org        False     BASIC       8.730536
# 1999          travis58@example.net        False     BASIC      19.454490
#
#      checkin_date checkout_date   room_rate
# 0      2020-04-04    2020-04-23  146.834507  \
# ...

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   guest_email         2000 non-null   object
#  1   has_rewards         2000 non-null   bool
#  2   room_type           2000 non-null   object
#  3   amenities_fee       2000 non-null   float64
#  4   checkin_date        2000 non-null   datetime64[ns]
#  5   checkout_date       1931 non-null   datetime64[ns]
#  6   room_rate           2000 non-null   float64
#  7   billing_address     2000 non-null   object
#  8   credit_card_number  2000 non-null   int64
# dtypes: bool(1), datetime64[ns](2), float64(2), int64(1), object(3)
# memory usage: 127.1+ KB

# %%
g.head()
# Out:
#                     guest_email  has_rewards room_type  amenities_fee
# 0         dsullivan@example.net        False     BASIC       8.324971  \
# 1          steven59@example.org        False     BASIC      17.000000
# 2         brandon15@example.net        False     BASIC      22.269158
# 3  humphreyjennifer@example.net        False     BASIC      25.468647
# 4       joshuabrown@example.net        False     BASIC      19.778311
#
#   checkin_date checkout_date   room_rate
# 0   2020-04-04    2020-04-23  146.834507  \
# 1   2020-06-27    2020-08-16  185.497813
# 2   2020-04-13    2020-04-07  151.115528
# 3   2020-05-22    2020-06-08  182.468031
# 4   2019-11-14    2019-10-27  195.497743
#
#                                      billing_address   credit_card_number
# 0   90469 Karla Knolls Apt. 781\nSusanberg, NC 28401     5161033759518980
# 1     1080 Ashley Creek Apt. 622\nWest Amy, NM 25058  4133047413145470000
# ...

# %% [markdown]
# # 1.What is the average amenities fee charged per room type?

# %%
gm['amenities_fee'].mean()
# Out:
# room_type
# BASIC     18.694103
# DELUXE    17.524165
# SUITE     15.848556
# Name: amenities_fee, dtype: float64

# %%
gm=g.groupby('room_type')

# %% [markdown]
# gc=g.copy()

# %%
gc=g.copy()

# %% [markdown]
# # 2.How many guests have a reward program and what is the average room rate they pay?

# %%
g[g['has_rewards']==True]['room_rate'].mean()
# Out:
# 166.39419014671307

# %% [markdown]
# # # 3.How many guests stayed in each room type?

# %%
g.groupby('room_type')['room_type'].value_counts()
# Out:
# room_type
# BASIC     1742
# DELUXE     178
# SUITE       80
# Name: count, dtype: int64

# %% [markdown]
# # 4.What is the total revenue generated by the hotel from the amenities fee?

# %%
g['amenities_fee'].sum()
# Out:
# 36952.312941357

# %% [markdown]
# # 5.Which credit card was used the most for payments?

# %%
g['total']=g['amenities_fee']+g['room_rate']

# %%
g.head(2)
# Out:
#              guest_email  has_rewards room_type  amenities_fee checkin_date
# 0  dsullivan@example.net        False     BASIC       8.324971   2020-04-04  \
# 1   steven59@example.org        False     BASIC      17.000000   2020-06-27
#
#   checkout_date   room_rate                                   billing_address
# 0    2020-04-23  146.834507  90469 Karla Knolls Apt. 781\nSusanberg, NC 28401  \
# 1    2020-08-16  185.497813    1080 Ashley Creek Apt. 622\nWest Amy, NM 25058
#
#     credit_card_number       total
# 0     5161033759518980  155.159478
# 1  4133047413145470000  202.497813

# %%
g['total'].max()
# Out:
# 364.01956939999997

# %%
g[g['total']==364.01956939999997]
# Out:
#                   guest_email  has_rewards room_type  amenities_fee
# 439  woodsjasmine@example.net        False     SUITE      18.559821  \
#
#     checkin_date checkout_date   room_rate
# 439   2020-07-17    2020-06-21  345.459749  \
#
#                                       billing_address  credit_card_number
# 439  8081 Schultz Camp Apt. 902\nThomasstad, NV 11145    4676953685055920  \
#
#           total
# 439  364.019569

# %% [markdown]
# # 6.What is the total revenue earned by the hotel?

# %%
g['total'].sum()
# Out:
# 349747.55371967703

# %%
g['total'].mean()
# Out:
# 174.87377685983853

# %%
g.sort_values('amenities_fee',ascending=False)
# Out:
#                      guest_email  has_rewards room_type  amenities_fee
# 1784  davismackenzie@example.net        False     BASIC      47.478848  \
# 305      mendezscott@example.org        False     BASIC      47.078524
# 498        carlnovak@example.com        False     BASIC      47.004387
# 1603      courtney56@example.net        False     BASIC      46.559123
# 431        owilliams@example.org        False     BASIC      46.275075
# ...                          ...          ...       ...            ...
# 1502       michael75@example.net         True     BASIC       0.000000
# 1622          odavis@example.com        False     BASIC       0.000000
# 116         isanchez@example.com        False     BASIC       0.000000
# 1156       matthew03@example.net        False     BASIC       0.000000
# 386    williamwilson@example.org        False     BASIC       0.000000
#
#      checkin_date checkout_date   room_rate
# 1784   2020-05-08    2020-04-26   95.030445  \
# ...
