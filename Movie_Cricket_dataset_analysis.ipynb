# %%
import numpy as np
import pandas as pd

# %%
t=pd.read_csv('E:\\python\\unix001\\mm\\New folder\\datasets-session-16\\kohli_ipl.csv')
t
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
t['runs'].sum()
# Out:
# 6634

# %%
t['match_no'].count()
# Out:
# 215

# %%
y=pd.read_csv('E:\\python\\unix001\\mm\\New folder\\datasets-session-16\\bollywood.csv',index_col='movie')
y.squeeze()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
y.sample(50)
# Out:
#                                                lead
# movie
# Mittal v/s Mittal                      Hazel Croney
# Challo Driver                      Vickrant Mahajan
# Batti Gul Meter Chalu                 Shahid Kapoor
# Gangs of Wasseypur                   Manoj Bajpayee
# Matrubhoomi                             Tulip Joshi
# Ssukh                                Aarti Chhabria
# Dil Pardesi Ho Gayaa                  Kapil Jhaveri
# Nayee Padosan                        Vikas Kalantri
# Mirzya (film)                   Harshvardhan Kapoor
# Mantra (2016 film)                     Rajat Kapoor
# Irudhi Suttru                              Madhavan
# Yeh Mera India                          Anupam Kher
# Dabangg                                 Salman Khan
# Happy Husbands (2011 film)                     Anay
# Dhoondte Reh Jaaoge                    Paresh Rawal
# Marjaavaan                         Riteish Deshmukh
# Heroes (2008 film)                      Sohail Khan
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1500 entries, Uri: The Surgical Strike to Awara Paagal Deewana
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lead    1500 non-null   object
# dtypes: object(1)
# memory usage: 55.7+ KB

# %%
y.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
y.sort_values(by='lead')
# Out:
#                                           lead
# movie
# Qaidi Band                          Aadar Jain
# Roar: Tigers of the Sundarbans    Aadil Chahal
# Lipstick Under My Burkha          Aahana Kumra
# Raat Gayi Baat Gayi?              Aamir Bashir
# Talaash: The Answer Lies Within     Aamir Khan
# ...                                        ...
# Dil Toh Deewana Hai                Zeenat Aman
# Sallu Ki Shaadi                    Zeenat Aman
# Strings of Passion                 Zeenat Aman
# Dunno Y... Na Jaane Kyon           Zeenat Aman
# Taj Mahal: An Eternal Love Story   Zulfi Sayed
#
# [1500 rows x 1 columns]

# %%
t
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
t.sort_values(by='runs').head(5)
# Out:
#      match_no  runs
# 86         87     0
# 210       211     0
# 206       207     0
# 205       206     0
# 90         91     0

# %%
t.value_counts()
# Out:
# match_no  runs
# 1         1       1
# 136       10      1
# 138       20      1
# 139       6       1
# 140       5       1
#                  ..
# 76        11      1
# 77        1       1
# 78        32      1
# 79        25      1
# 215       7       1
# Name: count, Length: 215, dtype: int64

# %%
t[t['runs']==0].size
# Out:
# 18

# %%
t
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
t['runs'].plot(kind='bar')
# Out:
# <Axes: >

# %%
t['runs'].head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='runs'>

# %%
t.columns
# Out:
# Index(['match_no', 'runs'], dtype='object')

# %%
t.values
# Out:
# array([[  1,   1],
#        [  2,  23],
#        [  3,  13],
#        [  4,  12],
#        [  5,   1],
#        [  6,   9],
#        [  7,  34],
#        [  8,   0],
#        [  9,  21],
#        [ 10,   3],
#        [ 11,  10],
#        [ 12,  38],
#        [ 13,   3],
#        [ 14,  11],
#        [ 15,  50],
#        [ 16,   2],
#        [ 17,  22],
#        [ 18,  19],
#        [ 19,  16],
#        [ 20,  15],
#        [ 21,  20],
#        [ 22,  38],
#        [ 23,  19],
#        [ 24,  24],
#        [ 25,   7],
#        [ 26,   2],
#        [ 27,  16],
#        [ 28,  17],
#        [ 29,  24],
#        [ 30,  38],
#        [ 31,  34],
#        [ 32,  42],
#        [ 33,  13],
#        [ 34,  58],
#        [ 35,   3],
#        [ 36,  14],
#        [ 37,  37],
#        [ 38,   9],
#        [ 39,  23],
#        [ 40,  12],
#        [ 41,  71],
#        [ 42,  35],
#        [ 43,  30],
#        [ 44,  56],
#        [ 45,  67],
#        [ 46,  27],
#        [ 47,  27],
# ...

# %%
y.values
# Out:
# array([['Vicky Kaushal'],
#        ['Vicky Ahuja'],
#        ['Anupam Kher'],
#        ...,
#        ['Vivek Oberoi'],
#        ['Ajay Devgn'],
#        ['Akshay Kumar']], dtype=object)

# %%
y.sample(5)
# Out:
#                             lead
# movie
# James (2005 film)  Mohit Ahlawat
# Filmistaan         Sharib Hashmi
# Risk (2007 film)    Vinod Khanna
# Matrubhoomi          Tulip Joshi
# Sweetiee Weds NRI  Himansh Kohli

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1500 entries, Uri: The Surgical Strike to Awara Paagal Deewana
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lead    1500 non-null   object
# dtypes: object(1)
# memory usage: 55.7+ KB

# %%
m=pd.read_csv('E:\\python\\unix001\\batsman_runs_ipl.csv')
m
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
m.count
# Out:
# <bound method DataFrame.count of              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]>

# %%
(m.value_counts()>1).tail(60)
# Out:
# batter             batsman_run
# Gurkeerat Singh    511            False
# H Das              2              False
# H Klaasen          66             False
# FY Fazal           183            False
# FA Allen           14             False
# JEC Franklin       327            False
# F du Plessis       3403           False
# DP Vijaykumar      1              False
# DPMD Jayawardene   1808           False
# DR Martyn          19             False
# DR Sams            44             False
# DR Shorey          13             False
# DR Smith           2385           False
# DS Kulkarni        104            False
# DS Lehmann         18             False
# DT Christian       460            False
# DT Patil           13             False
# DW Steyn           167            False
# E Lewis            654            False
# EJG Morgan         1406           False
# ER Dwivedi         24             False
# F Behardien        14             False
# HE van der Dussen  22             False
# ...

# %%
m.isnull().count()
# Out:
# batter         605
# batsman_run    605
# dtype: int64

# %%
m
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
m.duplicated().sum()
# Out:
# 0

# %%
t.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t.duplicated().sum()
#
# NameError: name 't' is not defined

# %%
y.duplicated().sum()
# Out:
# 934

# %%
m.values
# Out:
# array([['A Ashish Reddy', 280],
#        ['A Badoni', 161],
#        ['A Chandila', 4],
#        ...,
#        ['Younis Khan', 3],
#        ['Yuvraj Singh', 2754],
#        ['Z Khan', 117]], dtype=object)

# %%
m.rename(columns={'batter':'batters'},inplace=True)

# %%
m
# Out:
#             batters  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
l=pd.read_csv('C:\\Users\\PC\\Documents\\original_xt.csv')
l
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each
# 0         176337  Lightning Charging Cable                 1       14.95  \
# 1         176338     AA Batteries (4-pack)                 1        3.84
# 2         176339  Lightning Charging Cable                 1       14.95
# 3         176340      USB-C Charging Cable                 1       11.95
# 4         176341  Lightning Charging Cable                 1       14.95
# ...          ...                       ...               ...         ...
# 185945    176332     AA Batteries (4-pack)                 2        3.84
# 185946    176333     AA Batteries (4-pack)                 2        3.84
# 185947    176334          Wired Headphones                 1       11.99
# 185948    176335    AAA Batteries (4-pack)                 1        2.99
# 185949    176336    AAA Batteries (4-pack)                 3        2.99
#
#          OrderDate                        Purchase Address  total_sales
# ...

# %%
l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   OrderDate         185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   total_sales       185950 non-null  float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 9.9+ MB

# %%
y
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
y['lead']
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
l
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each
# 0         176337  Lightning Charging Cable                 1       14.95  \
# 1         176338     AA Batteries (4-pack)                 1        3.84
# 2         176339  Lightning Charging Cable                 1       14.95
# 3         176340      USB-C Charging Cable                 1       11.95
# 4         176341  Lightning Charging Cable                 1       14.95
# ...          ...                       ...               ...         ...
# 185945    176332     AA Batteries (4-pack)                 2        3.84
# 185946    176333     AA Batteries (4-pack)                 2        3.84
# 185947    176334          Wired Headphones                 1       11.99
# 185948    176335    AAA Batteries (4-pack)                 1        2.99
# 185949    176336    AAA Batteries (4-pack)                 3        2.99
#
#          OrderDate                        Purchase Address  total_sales
# ...

# %%
l[['Order ID','Product','Price Each','Quantity Ordered']]
# Out:
#         Order ID                   Product  Price Each  Quantity Ordered
# 0         176337  Lightning Charging Cable       14.95                 1
# 1         176338     AA Batteries (4-pack)        3.84                 1
# 2         176339  Lightning Charging Cable       14.95                 1
# 3         176340      USB-C Charging Cable       11.95                 1
# 4         176341  Lightning Charging Cable       14.95                 1
# ...          ...                       ...         ...               ...
# 185945    176332     AA Batteries (4-pack)        3.84                 2
# 185946    176333     AA Batteries (4-pack)        3.84                 2
# 185947    176334          Wired Headphones       11.99                 1
# 185948    176335    AAA Batteries (4-pack)        2.99                 1
# 185949    176336    AAA Batteries (4-pack)        2.99                 3
#
# [185950 rows x 4 columns]

# %%
l
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each
# 0         176337  Lightning Charging Cable                 1       14.95  \
# 1         176338     AA Batteries (4-pack)                 1        3.84
# 2         176339  Lightning Charging Cable                 1       14.95
# 3         176340      USB-C Charging Cable                 1       11.95
# 4         176341  Lightning Charging Cable                 1       14.95
# ...          ...                       ...               ...         ...
# 185945    176332     AA Batteries (4-pack)                 2        3.84
# 185946    176333     AA Batteries (4-pack)                 2        3.84
# 185947    176334          Wired Headphones                 1       11.99
# 185948    176335    AAA Batteries (4-pack)                 1        2.99
# 185949    176336    AAA Batteries (4-pack)                 3        2.99
#
#          OrderDate                        Purchase Address  total_sales
# ...

# %%
l.iloc[0]
# Out:
# Order ID                                          176337
# Product                         Lightning Charging Cable
# Quantity Ordered                                       1
# Price Each                                         14.95
# OrderDate                                     24-03-2019
# Purchase Address    410 Forest St, Los Angeles, CA 90001
# total_sales                                        14.95
# Name: 0, dtype: object

# %%
l.iloc[10:15]
# Out:
#     Order ID                   Product  Quantity Ordered  Price Each
# 10    176347  Lightning Charging Cable                 1       14.95  \
# 11    176348    AAA Batteries (4-pack)                 2        2.99
# 12    176349          Wired Headphones                 1       11.99
# 13    176350      USB-C Charging Cable                 1       11.95
# 14    176351    AAA Batteries (4-pack)                 2        2.99
#
#      OrderDate                  Purchase Address  total_sales
# 10  09-03-2019    830 South St, Boston, MA 02215        14.95
# 11  15-03-2019  940 Meadow St, Seattle, WA 98101         5.98
# 12  11-03-2019       47 4th St, Boston, MA 02215        11.99
# 13  09-03-2019      676 2nd St, Boston, MA 02215        11.95
# 14  02-03-2019    957 1st St, Portland, OR 97035         5.98

# %%
l
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each
# 0         176337  Lightning Charging Cable                 1       14.95  \
# 1         176338     AA Batteries (4-pack)                 1        3.84
# 2         176339  Lightning Charging Cable                 1       14.95
# 3         176340      USB-C Charging Cable                 1       11.95
# 4         176341  Lightning Charging Cable                 1       14.95
# ...          ...                       ...               ...         ...
# 185945    176332     AA Batteries (4-pack)                 2        3.84
# 185946    176333     AA Batteries (4-pack)                 2        3.84
# 185947    176334          Wired Headphones                 1       11.99
# 185948    176335    AAA Batteries (4-pack)                 1        2.99
# 185949    176336    AAA Batteries (4-pack)                 3        2.99
#
#          OrderDate                        Purchase Address  total_sales
# ...

# %%
l.iloc[[0,5,3]]
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each
# 0    176337  Lightning Charging Cable                 1       14.95  \
# 5    176342  Apple Airpods Headphones                 1      150.00
# 3    176340      USB-C Charging Cable                 1       11.95
#
#     OrderDate                        Purchase Address  total_sales
# 0  24-03-2019    410 Forest St, Los Angeles, CA 90001        14.95
# 5  29-03-2019      865 Lincoln St, Portland, OR 97035       150.00
# 3  10-03-2019  708 Walnut St, San Francisco, CA 94016        11.95

# %%
l.loc[185945]
# Out:
# Order ID                                   176332
# Product                     AA Batteries (4-pack)
# Quantity Ordered                                2
# Price Each                                   3.84
# OrderDate                              22-03-2019
# Purchase Address    330 4th St, Atlanta, GA 30301
# total_sales                                  7.68
# Name: 185945, dtype: object

# %%
l
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each
# 0         176337  Lightning Charging Cable                 1       14.95  \
# 1         176338     AA Batteries (4-pack)                 1        3.84
# 2         176339  Lightning Charging Cable                 1       14.95
# 3         176340      USB-C Charging Cable                 1       11.95
# 4         176341  Lightning Charging Cable                 1       14.95
# ...          ...                       ...               ...         ...
# 185945    176332     AA Batteries (4-pack)                 2        3.84
# 185946    176333     AA Batteries (4-pack)                 2        3.84
# 185947    176334          Wired Headphones                 1       11.99
# 185948    176335    AAA Batteries (4-pack)                 1        2.99
# 185949    176336    AAA Batteries (4-pack)                 3        2.99
#
#          OrderDate                        Purchase Address  total_sales
# ...

# %%
l.iloc[0:5,0:2]
# Out:
#    Order ID                   Product
# 0    176337  Lightning Charging Cable
# 1    176338     AA Batteries (4-pack)
# 2    176339  Lightning Charging Cable
# 3    176340      USB-C Charging Cable
# 4    176341  Lightning Charging Cable

# %%
i=pd.read_csv('E:\\python\\unix001\\ipl-matches.csv')
i.head(60)
# Out:
#          ID         City        Date Season  MatchNumber
# 0   1312200    Ahmedabad  2022-05-29   2022        Final  \
# 1   1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2   1312198      Kolkata  2022-05-25   2022   Eliminator
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4   1304116       Mumbai  2022-05-22   2022           70
# 5   1304115       Mumbai  2022-05-21   2022           69
# 6   1304114       Mumbai  2022-05-20   2022           68
# 7   1304113       Mumbai  2022-05-19   2022           67
# 8   1304112  Navi Mumbai  2022-05-18   2022           66
# 9   1304111       Mumbai  2022-05-17   2022           65
# 10  1304110  Navi Mumbai  2022-05-16   2022           64
# 11  1304109       Mumbai  2022-05-15   2022           63
# 12  1304108       Mumbai  2022-05-15   2022           62
# 13  1304107         Pune  2022-05-14   2022           61
# 14  1304106       Mumbai  2022-05-13   2022           60
# ...

# %%
k=i[i['MatchNumber']=='Final']

# %%
k[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
s=i[i['SuperOver']=='Y']
s.shape
# Out:
# (14, 20)

# %%
i.head(60)
# Out:
#          ID         City        Date Season  MatchNumber
# 0   1312200    Ahmedabad  2022-05-29   2022        Final  \
# 1   1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2   1312198      Kolkata  2022-05-25   2022   Eliminator
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4   1304116       Mumbai  2022-05-22   2022           70
# 5   1304115       Mumbai  2022-05-21   2022           69
# 6   1304114       Mumbai  2022-05-20   2022           68
# 7   1304113       Mumbai  2022-05-19   2022           67
# 8   1304112  Navi Mumbai  2022-05-18   2022           66
# 9   1304111       Mumbai  2022-05-17   2022           65
# 10  1304110  Navi Mumbai  2022-05-16   2022           64
# 11  1304109       Mumbai  2022-05-15   2022           63
# 12  1304108       Mumbai  2022-05-15   2022           62
# 13  1304107         Pune  2022-05-14   2022           61
# 14  1304106       Mumbai  2022-05-13   2022           60
# ...

# %%
i[(i['City']=='Kolkata') & (i['WinningTeam']=='Chennai Super Kings')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders  \
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field  \
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
((i[i['TossWinner']==i['WinningTeam']].shape[0])/i.shape[0])*100
# Out:
# 51.473684210526315

# %%
u=pd.read_csv('E:\\python\\unix001\\movies.csv')
u.head()
# Out:
#                                 title_x    imdb_id
# 0              Uri: The Surgical Strike  tt8291224  \
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...  \
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...  \
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
u[(u['imdb_rating']>8) & (u['imdb_votes']>10000)]
# Out:
#                           title_x     imdb_id
# 0        Uri: The Surgical Strike   tt8291224  \
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
len(u[u['genres'].str.split('|').apply(lambda v : 'Action' in v) & (u['imdb_rating']>7.5)])
# Out:
# 33

# %%
len(u[u['genres'].str.contains('Action') & (u['imdb_rating']>7.5)])
# Out:
# 33

# %%
i.head()
# Out:
#         ID       City        Date Season  MatchNumber
# 0  1312200  Ahmedabad  2022-05-29   2022        Final  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2
# 0             Rajasthan Royals        Gujarat Titans  \
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  \
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
i[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2
# 0               Rajasthan Royals               Gujarat Titans  \
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
r=i[(i['Team1']=='Royal Challengers Bangalore') & (i['Team2']=='Chennai Super Kings')]
k=i[(i['Team2']=='Royal Challengers Bangalore') & (i['Team1']=='Chennai Super Kings')]
r
# Out:
#           ID            City        Date   Season  MatchNumber
# 25   1304095            Pune  2022-05-04     2022           49  \
# 99   1254113         Sharjah  2021-09-24     2021           35
# 150  1216544             NaN  2020-10-25  2020/21           44
# 170  1216525             NaN  2020-10-10  2020/21           25
# 216  1178414       Bengaluru  2019-04-21     2019           39
# 253  1175356         Chennai  2019-03-23     2019            1
# 279  1136595            Pune  2018-05-05     2018           35
# 290  1136584       Bengaluru  2018-04-25     2018           24
# 473   829745       Bangalore  2015-04-22     2015           20
# 498   734035       Bangalore  2014-05-24     2014           53
# 558   598068       Bangalore  2013-05-18     2013           70
# 705   501268          Mumbai  2011-05-24     2011  Qualifier 1
# 707   501266       Bangalore  2011-05-22     2011           69
# 817   419123       Bangalore  2010-03-23  2009/10           18
# ...

# %%
r['WinningTeam'].value_counts()+k['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Chennai Super Kings            19
# Royal Challengers Bangalore    10
# Name: count, dtype: int64

# %%
k['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Chennai Super Kings            9
# Royal Challengers Bangalore    2
# Name: count, dtype: int64

# %%
i
# Out:
#           ID        City        Date   Season  MatchNumber
# 0    1312200   Ahmedabad  2022-05-29     2022        Final  \
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2
# 0               Rajasthan Royals               Gujarat Titans  \
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
u
# Out:
#                                    title_x     imdb_id
# 0                 Uri: The Surgical Strike   tt8291224  \
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path
# 0     https://upload.wikimedia.org/wikipedia/en/thum...  \
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
i.head(2)
# Out:
#         ID       City        Date Season  MatchNumber
# 0  1312200  Ahmedabad  2022-05-29   2022        Final  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2
# 0             Rajasthan Royals    Gujarat Titans  \
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N  \
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya  \
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  \
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
i['Player_of_Match'].value_counts().contains('virat')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 i['Player_of_Match'].value_counts().contains('virat')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'contains'

# %%
i[~i['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
i
# Out:
#           ID        City        Date   Season  MatchNumber
# 0    1312200   Ahmedabad  2022-05-29     2022        Final  \
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2
# 0               Rajasthan Royals               Gujarat Titans  \
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
i['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
(i['Team1'].value_counts()+i['Team2'].value_counts()).sort_values(ascending=False).head().plot(kind='bar')
# Out:
# <Axes: >

# %%
u=u.drop(columns='wiki_link')

# %%
u['runtime'].sort_values(ascending=False).sample(10)
# Out:
# 1054    128
# 1147     90
# 354     161
# 143     104
# 711     115
# 626     152
# 1493    165
# 419     124
# 1019    132
# 630     137
# Name: runtime, dtype: object

# %%
u.sort_values(by='imdb_votes',ascending=False)
# Out:
#                      title_x     imdb_id                 title_y
# 912                 3 Idiots   tt1187043                3 Idiots  \
# 1127        Taare Zameen Par   tt0986264     Like Stars on Earth
# 567                PK (film)   tt2338151                      PK
# 354            Dangal (film)   tt5074352                  Dangal
# 74               Dil Bechara   tt8110330             Dil Bechara
# ...                      ...         ...                     ...
# 331       Ek Kahani Julie Ki   tt7997334      Ek Kahani Julie Ki
# 472       Dee Saturday Night  tt10635372      Dee Saturday Night
# 298   Khel Toh Ab Shuru Hoga   tt6656806  khel toh ab shuru hoga
# 407              I Love Desi   tt4718678             I Love Desi
# 479     Anuradha (2014 film)   tt3482198                Anuradha
#
#               original_title  is_adult  year_of_release runtime
# 912                 3 Idiots         0             2009     170  \
# ...

# %%
u.sort_values(['year_of_release','title_x']).head(60)
# Out:
#                                 title_x    imdb_id
# 1575                        Aalavandhan  tt0294264  \
# 1576   Aamdani Atthanni Kharcha Rupaiya  tt0305173
# 1577                 Aashiq (2001 film)  tt0273406
# 1579                Ajnabee (2001 film)  tt0278291
# 1578                    Aks (2001 film)  tt0289845
# 1582                 Albela (2001 film)  tt0118578
# 1581                       Aśoka (film)  tt0249371
# 1512                              Baaja  tt0405722
# 1583             Bas Itna Sa Khwaab Hai  tt0283911
# 1586           Bengal Tiger (2001 film)  tt0477574
# 1585                     Bhairav (film)  tt0466208
# 1580                      Censor (film)  tt0272543
# 1589                        Chandni Bar  tt0267363
# 1587  Chhupa Rustam: A Musical Thriller  tt0279021
# 1572          Chori Chori Chupke Chupke  tt0256692
# 1588                       Daman (film)  tt0273164
# 1595                             Dattak  tt0284999
# ...

# %%
u.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id
# 1623                              Zubeidaa   tt0255713  \
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                    title_y
# 1623                              Zubeidaa  \
# 1625                  Yeh Zindagi Ka Safar
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar
# 1620              Yeh Raaste Hain Pyaar Ke
# 1573                            Yaadein...
# ...

# %%
f=pd.read_csv('E:\\python\\unix001\\batsman_runs_ipl.csv')
f
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
f['batting_rank']=f['batsman_run'].rank(ascending=False)

# %%
f
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
f.sort_values(by='batsman_run',ascending=False).head(60)
# Out:
#                batter  batsman_run  batting_rank
# 569           V Kohli         6634           1.0
# 462          S Dhawan         6244           2.0
# 130         DA Warner         5883           3.0
# 430         RG Sharma         5881           4.0
# 493          SK Raina         5536           5.0
# 27     AB de Villiers         5181           6.0
# 108          CH Gayle         4997           7.0
# 339          MS Dhoni         4978           8.0
# 452        RV Uthappa         4954           9.0
# 256        KD Karthik         4377          10.0
# 174         G Gambhir         4217          11.0
# 60          AT Rayudu         4190          12.0
# 46          AM Rahane         4074          13.0
# 263          KL Rahul         3895          14.0
# 511         SR Watson         3880          15.0
# 328         MK Pandey         3657          16.0
# 519         SV Samson         3526          17.0
# 251        KA Pollard         3437          18.0
# ...

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   batter        605 non-null    object
#  1   batsman_run   605 non-null    int64
#  2   batting_rank  605 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 14.3+ KB

# %%
i
# Out:
#           ID        City        Date   Season  MatchNumber
# 0    1312200   Ahmedabad  2022-05-29     2022        Final  \
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2
# 0               Rajasthan Royals               Gujarat Titans  \
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...
