# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
audible=pd.read_csv('F:\\d_data\\New folder\\New folder (8)\\audible_uncleaned.csv')
audible

# we have almost 87k records and 8 colomn
#
# Out:
#                                              name                     author
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton  \
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
audible.shape
# There are almost 87k records and 8 colomns
# Out:
# (87489, 8)

# %%
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  object
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %%
audible['releasedate']
# Out:
# 0        2004-08-08
# 1        2001-05-18
# 2        2006-11-20
# 3        2005-10-21
# 4        2013-01-10
#             ...
# 87484    2009-03-17
# 87485    2021-02-17
# 87486    1930-12-16
# 87487    2023-02-11
# 87488    2007-03-17
# Name: releasedate, Length: 87489, dtype: object

# %%
pd.to_datetime(audible['releasedate'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 pd.to_datetime(audible['releasedate'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
# ...

# %%
# time data "26-10-2000" doesn't match format "%Y-%m-%d", at position 386.
audible['releasedate'][audible['releasedate']=="26-10-2000"]
# Out:
# 968      26-10-2000
# 3734     26-10-2000
# 7699     26-10-2000
# 11716    26-10-2000
# 14314    26-10-2000
# 17798    26-10-2000
# 21165    26-10-2000
# 21879    26-10-2000
# 21964    26-10-2000
# 26142    26-10-2000
# 38166    26-10-2000
# 46913    26-10-2000
# 47070    26-10-2000
# 48296    26-10-2000
# 49147    26-10-2000
# 49676    26-10-2000
# 53823    26-10-2000
# 54228    26-10-2000
# 69443    26-10-2000
# Name: releasedate, dtype: object

# %%
corrected_dates = []

for i in audible['releasedate']:
    try:
        f_date = pd.to_datetime(i, format='%d-%m-%Y', errors='raise')
    except ValueError:
        try:
            f_date = pd.to_datetime(i, format='%Y-%m-%d', errors='raise')
        except ValueError:
            try:
                f_date = pd.to_datetime(i, format='%d-%m-%y', errors='raise')
            except ValueError:
                f_date = pd.NaT
    corrected_dates.append(f_date)

audible['releasedate'] = corrected_dates

# %%
audible
# Out:
#                                              name                     author
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton  \
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  datetime64[ns]
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 5.3+ MB

# %%
audible['time']
# Out:
# 0         2 hrs and 20 mins
# 1         13 hrs and 8 mins
# 2          2 hrs and 3 mins
# 3        11 hrs and 16 mins
# 4                    10 hrs
#                 ...
# 87484     7 hrs and 34 mins
# 87485     10 hrs and 7 mins
# 87486     19 hrs and 4 mins
# 87487      4 hrs and 8 mins
# 87488       6 hrs and 1 min
# Name: time, Length: 87489, dtype: object

# %%
audible['time'][0]
# Out:
# '2 hrs and 20 mins'

# %%
# convert '2 hrs and 20 mins' into 2:30:00

# %%
def convert_time(time_str):
    parts = time_str.split()
    hours = 0
    minutes = 0
    print(parts)

    for i in range(len(parts)):
        if parts[i] == 'hrs' or parts[i] ==  'hr':
            hours = int(parts[i - 1])
            print(hours)
        elif parts[i] == 'mins':
            minutes = int(parts[i - 1])
            print(minutes)

    return f'{hours:02}:{minutes:02}:00'

# %%
def convert_time(time_str):
    parts = time_str.split()
    hours = 0
    minutes = 0
    
    for i in range(len(parts)):
        if parts[i] == 'hrs' or parts[i] ==  'hr':
            hours = int(parts[i - 1])
        elif parts[i] == 'mins':
            minutes = int(parts[i - 1])
    return f'{hours:02}:{minutes:02}:00'
    
audible['time']=audible['time'].apply(convert_time)

# %%
audible
# Out:
#                                              name                     author
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton  \
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
audible.head()
# Out:
#                                          name                     author
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton  \
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator      time releasedate language
# 0      Narratedby:BillLobely  02:20:00  2004-08-08  English  \
# 1   Narratedby:RobbieDaymond  13:08:00  2001-05-18  English
# 2      Narratedby:DanRussell  02:03:00  2006-11-20  English
# 3  Narratedby:SoneelaNankani  11:16:00  2005-10-21  English
# 4  Narratedby:JesseBernstein  10:00:00  2013-01-10  English
#
#                            stars price
# 0     5 out of 5 stars34 ratings   468
# 1   4.5 out of 5 stars41 ratings   820
# 2   4.5 out of 5 stars38 ratings   410
# ...

# %%
audible['author']=audible['author'].str.split(':').str.get(1)

# %%
audible.head()
# Out:
#                                          name           author
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton  \
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#                     narrator      time releasedate language
# 0      Narratedby:BillLobely  02:20:00  2004-08-08  English  \
# 1   Narratedby:RobbieDaymond  13:08:00  2001-05-18  English
# 2      Narratedby:DanRussell  02:03:00  2006-11-20  English
# 3  Narratedby:SoneelaNankani  11:16:00  2005-10-21  English
# 4  Narratedby:JesseBernstein  10:00:00  2013-01-10  English
#
#                            stars price
# 0     5 out of 5 stars34 ratings   468
# 1   4.5 out of 5 stars41 ratings   820
# 2   4.5 out of 5 stars38 ratings   410
# 3   4.5 out of 5 stars12 ratings   615
# ...

# %%
audible['narrator']=audible['narrator'].str.split(':').str.get(1)

# %%
audible.head()
# Out:
#                                          name           author
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton  \
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#          narrator      time releasedate language
# 0      BillLobely  02:20:00  2004-08-08  English  \
# 1   RobbieDaymond  13:08:00  2001-05-18  English
# 2      DanRussell  02:03:00  2006-11-20  English
# 3  SoneelaNankani  11:16:00  2005-10-21  English
# 4  JesseBernstein  10:00:00  2013-01-10  English
#
#                            stars price
# 0     5 out of 5 stars34 ratings   468
# 1   4.5 out of 5 stars41 ratings   820
# 2   4.5 out of 5 stars38 ratings   410
# 3   4.5 out of 5 stars12 ratings   615
# 4  4.5 out of 5 stars181 ratings   820

# %%
audible['stars']
# Out:
# 0           5 out of 5 stars34 ratings
# 1         4.5 out of 5 stars41 ratings
# 2         4.5 out of 5 stars38 ratings
# 3         4.5 out of 5 stars12 ratings
# 4        4.5 out of 5 stars181 ratings
#                      ...
# 87484                    Not rated yet
# 87485                    Not rated yet
# 87486                    Not rated yet
# 87487                    Not rated yet
# 87488                    Not rated yet
# Name: stars, Length: 87489, dtype: object

# %%
audible['stars'].str.split('stars')
# Out:
# 0           [5 out of 5 , 34 ratings]
# 1         [4.5 out of 5 , 41 ratings]
# 2         [4.5 out of 5 , 38 ratings]
# 3         [4.5 out of 5 , 12 ratings]
# 4        [4.5 out of 5 , 181 ratings]
#                      ...
# 87484                 [Not rated yet]
# 87485                 [Not rated yet]
# 87486                 [Not rated yet]
# 87487                 [Not rated yet]
# 87488                 [Not rated yet]
# Name: stars, Length: 87489, dtype: object

# %%
audible['stars']=audible['stars'].str.split('stars').str.get(0)

# %%
audible['ratings']=audible['stars'].str.split('stars').str.get(1)

# %%
audible
# Out:
#                                              name           author
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton  \
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator      time releasedate language          stars price
# 0          BillLobely  02:20:00  2004-08-08  English    5 out of 5    468  \
# ...

# %%
import re

def extract_ratings(rating_str):
    pattern = r'(\d+\.\d+|\d+) out of 5'
    match = re.search(pattern, rating_str)

    if match:
        return match.group(1) 
    else:
        return None
audible['stars']=audible['stars'].apply(extract_ratings)

# %%
audible
# Out:
#                                              name           author
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton  \
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator      time releasedate language stars price      ratings
# 0          BillLobely  02:20:00  2004-08-08  English     5   468   34 ratings
# ...

# %%
audible['ratings']=audible['ratings'].str.split(' ').str.get(0)

# %%
audible
# Out:
#                                              name           author
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton  \
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator      time releasedate language stars price ratings
# 0          BillLobely  02:20:00  2004-08-08  English     5   468      34
# ...
